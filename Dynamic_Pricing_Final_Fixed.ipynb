# %% [markdown]
# <a href="https://colab.research.google.com/github/susmita99-collab/Summer-Analytics-2025-Assignment/blob/main/Dynamic_Pricing_Final_Fixed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 📦 Step 0: Install required libraries
# !pip install pathway bokeh panel --quiet

# 🧠 Step 1: Import libraries
import numpy as np
import pandas as pd
import pathway as pw
import datetime
import bokeh.plotting
import panel as pn

# 📥 Step 2: Load and preprocess data
# Upload your 'dataset.csv' to Colab before running this
df = pd.read_csv('dataset.csv')

# ✅ Fix: Create Timestamp column with correct datetime format
df['Timestamp'] = pd.to_datetime(df['LastUpdatedDate'] + ' ' + df['LastUpdatedTime'],
                                  format='%d-%m-%Y %H:%M:%S')

# Sort and save required columns to a new CSV for streaming
df = df.sort_values('Timestamp').reset_index(drop=True)
df[['Timestamp', 'Occupancy', 'Capacity', 'QueueLength', 'TrafficConditionNearby', 'IsSpecialDay', 'VehicleType']].to_csv("parking_stream.csv", index=False)

# 📐 Step 3: Define schema for Pathway
class ParkingSchema(pw.Schema):
    Timestamp: str
    Occupancy: int
    Capacity: int
    QueueLength: int
    TrafficConditionNearby: int
    IsSpecialDay: int
    VehicleType: str

data = pw.demo.replay_csv("parking_stream.csv", schema=ParkingSchema, input_rate=1000)

# 🕓 Step 4: Add time columns
fmt = "%Y-%m-%d %H:%M:%S"

data_with_time = data.with_columns(
    t = data.Timestamp.dt.strptime(fmt),
    day = data.Timestamp.dt.strptime(fmt).dt.strftime("%Y-%m-%dT00:00:00")
)

# 🧮 Step 5: Demand-based pricing logic
def vehicle_type_weight(vehicle):
    weights = {"car": 1.0, "bike": 0.5, "truck": 1.5}
    return weights.get(vehicle.lower(), 1.0)

extended = data_with_time.with_columns(
    demand = (
        0.4 * (data_with_time.Occupancy / data_with_time.Capacity)
        + 0.2 * data_with_time.QueueLength
        - 0.2 * data_with_time.TrafficConditionNearby
        + 0.1 * data_with_time.IsSpecialDay
        + 0.1 * pw.apply(vehicle_type_weight, data_with_time.VehicleType)
    )
)

# 💰 Step 6: Normalize demand and calculate price
BASE_PRICE = 10
MAX_MULTIPLIER = 2.0
MIN_MULTIPLIER = 0.5

windowed = (
    extended.windowby(
        pw.this.t,
        instance=pw.this.day,
        window=pw.temporal.tumbling(datetime.timedelta(days=1)),
        behavior=pw.temporal.exactly_once_behavior()
    )
    .reduce(
        t = pw.this._pw_window_end,
        demand_mean = pw.reducers.mean(pw.this.demand)
    )
    .with_columns(
        price = pw.apply(
            lambda d: max(MIN_MULTIPLIER, min(MAX_MULTIPLIER, 1 + d)) * BASE_PRICE,
            pw.this.demand_mean
        )
    )
)

# 📊 Step 7: Visualize using Bokeh
pn.extension()

def price_plotter(source):
    fig = bokeh.plotting.figure(
        height=400,
        width=800,
        title="Dynamic Parking Price (Daily)",
        x_axis_type="datetime",
    )
    fig.line("t", "price", source=source, line_width=2, color="green")
    fig.circle("t", "price", source=source, size=6, color="red")
    return fig

viz = windowed.plot(price_plotter, sorting_col="t")
pn.Column(viz).servable()

# 🚀 Step 8: Run the Pathway stream processor
# %%capture --no-display
pw.run()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3-4258632274.py in <cell line: 0>()
#      47     return weights.get(vehicle.lower(), 1.0)
#      48
# ---> 49 extended = data_with_time.with_columns(
#      50     demand = (
#      51         0.4 * (data_with_time.Occupancy / data_with_time.Capacity)
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/trace.py in _pathway_trace_marker(*args, **kwargs)
#     132             return func(*args, **kwargs)
#     133         except Exception as e:
# --> 134             _reraise_with_user_frame(e)
#     135
#     136     return _pathway_trace_marker
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/trace.py in _reraise_with_user_frame(e, trace)
#      98
#      99     if hasattr(e, "_pathway_trace_note"):
# --> 100         raise e
#     101
#     102     if trace is None:
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/desugaring.py in wrapper(*args, **kwargs)
#     359                 for key, value in kwargs.items()
#     360             }
# --> 361         return func(*args, **kwargs)
#     362
#     363     return wrapper
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/table.py in with_columns(self, *args, **kwargs)
#    1657         10  | Tom   | 1   | 10
#    1658         """
# -> 1659         other = self.select(*args, **kwargs)
#    1660         columns = dict(self)
#    1661         columns.update(other)
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/trace.py in _pathway_trace_marker(*args, **kwargs)
#     132             return func(*args, **kwargs)
#     133         except Exception as e:
# --> 134             _reraise_with_user_frame(e)
#     135
#     136     return _pathway_trace_marker
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/trace.py in _reraise_with_user_frame(e, trace)
#     108         add_pathway_trace_note(e, user_frame)
#     109
# --> 110     raise e
#     111
#     112
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/desugaring.py in wrapper(*args, **kwargs)
#     359                 for key, value in kwargs.items()
#     360             }
# --> 361         return func(*args, **kwargs)
#     362
#     363     return wrapper
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/arg_handlers.py in inner(*args, **kwargs)
#      17         def inner(*args, **kwargs):
#      18             args, kwargs = handler(*args, **kwargs)
# ---> 19             return func(*args, **kwargs)
#      20
#      21         return inner
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/decorators.py in wrapper(*args, **kwargs)
#      20     @wraps(func)
#      21     def wrapper(*args, **kwargs):
# ---> 22         return G.add_operator(
#      23             lambda id: operator_cls(fn_spec, id),
#      24             lambda operator: operator(*args, **kwargs),
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/parse_graph.py in add_operator(self, create_node, call_operator, special, require_error_log)
#     149             self.add_error_log(global_log=True)  # deferred global log creation
#     150         node.set_error_log(self.error_log_stack[-1] if require_error_log else None)
# --> 151         result = call_operator(node)
#     152         self._current_scope.add_node(node, special=special)
#     153         self.unused_operators = True
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/decorators.py in <lambda>(operator)
#      22         return G.add_operator(
#      23             lambda id: operator_cls(fn_spec, id),
# ---> 24             lambda operator: operator(*args, **kwargs),
#      25         )
#      26
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/operator.py in __call__(self, *args, **kwargs)
#     224         self._prepare_inputs(input)
#     225
# --> 226         result = self.func_spec.func(*args, **kwargs)
#     227         result = as_arg_tuple(result)
#     228         self._prepare_outputs(result)
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/table.py in select(self, *args, **kwargs)
#     424             new_columns.append((new_name, column))
#     425
# --> 426         return self._with_same_universe(*new_columns)
#     427
#     428     @trace_user_frame
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/table.py in _with_same_universe(self, schema, *columns)
#    2361         schema: type[Schema] | None = None,
#    2362     ) -> Table:
# -> 2363         return Table(
#    2364             _columns=dict(columns),
#    2365             _schema=schema,
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/table.py in __init__(self, _columns, _context, _schema)
#     115     ):
#     116         if _schema is None:
# --> 117             _schema = schema_from_columns(_columns, _context.id_column)
#     118         super().__init__(_context)
#     119         self._columns = dict(_columns)
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/schema.py in schema_from_columns(columns, id_column)
#      40
#      41     return schema_builder(
# ---> 42         columns={
#      43             name: ColumnDefinition.from_properties(c.properties)
#      44             for name, c in columns.items()
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/schema.py in <dictcomp>(.0)
#      41     return schema_builder(
#      42         columns={
# ---> 43             name: ColumnDefinition.from_properties(c.properties)
#      44             for name, c in columns.items()
#      45         },
#
# /usr/lib/python3.11/functools.py in __get__(self, instance, owner)
#     999                 val = cache.get(self.attrname, _NOT_FOUND)
#    1000                 if val is _NOT_FOUND:
# -> 1001                     val = self.func(instance)
#    1002                     try:
#    1003                         cache[self.attrname] = val
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/column.py in properties(self)
#     135     @cached_property
#     136     def properties(self) -> cp.ColumnProperties:
# --> 137         return self.context.column_properties(self)
#     138
#     139     @cached_property
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/column.py in column_properties(self, column)
#     330
#     331     def column_properties(self, column: ColumnWithContext) -> cp.ColumnProperties:
# --> 332         return self._column_properties_evaluator(self).eval(column)
#     333
#     334     def __init_subclass__(
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/column_properties.py in eval(self, column)
#      24     def eval(self, column: clmn.ColumnWithContext) -> ColumnProperties:
#      25         return ColumnProperties(
# ---> 26             dtype=column.context_dtype, append_only=self._append_only(column)
#      27         )
#      28
#
# /usr/lib/python3.11/functools.py in __get__(self, instance, owner)
#     999                 val = cache.get(self.attrname, _NOT_FOUND)
#    1000                 if val is _NOT_FOUND:
# -> 1001                     val = self.func(instance)
#    1002                     try:
#    1003                         cache[self.attrname] = val
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/column.py in context_dtype(self)
#     208     @cached_property
#     209     def context_dtype(self) -> dt.DType:
# --> 210         return self.context.expression_type(self.expression)
#     211
#     212
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/column.py in expression_type(self, expression)
#     301
#     302     def expression_type(self, expression: ColumnExpression) -> dt.DType:
# --> 303         return self.expression_with_type(expression)._dtype
#     304
#     305     @abstractmethod
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/column.py in expression_with_type(self, expression)
#     309         from pathway.internals.type_interpreter import TypeInterpreterState
#     310
# --> 311         return self._get_type_interpreter().eval_expression(
#     312             expression, state=TypeInterpreterState()
#     313         )
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/expression_visitor.py in eval_expression(self, expression, **kwargs)
#     123 class IdentityTransform(ExpressionVisitor):
#     124     def eval_expression(self, expression: ColExprT, **kwargs) -> ColExprT:
# --> 125         ret = super().eval_expression(expression, **kwargs)
#     126         if hasattr(expression, "_dtype"):
#     127             ret._dtype = expression._dtype
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/expression_visitor.py in eval_expression(self, expression, **kwargs)
#      42         if not isinstance(expression, expr.ColumnExpression):
#      43             return self.eval_any(expression, **kwargs)
# ---> 44         return impl[type(expression)](expression, **kwargs)
#      45
#      46     @abstractmethod
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/type_interpreter.py in eval_binary_op(self, expression, state, **kwargs)
#     103         **kwargs,
#     104     ) -> expr.ColumnBinaryOpExpression:
# --> 105         expression = super().eval_binary_op(expression, state=state, **kwargs)
#     106         left_dtype = expression._left._dtype
#     107         right_dtype = expression._right._dtype
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/expression_visitor.py in eval_binary_op(self, expression, **kwargs)
#     145     ) -> expr.ColumnBinaryOpExpression:
#     146         left = self.eval_expression(expression._left, **kwargs)
# --> 147         right = self.eval_expression(expression._right, **kwargs)
#     148         return expr.ColumnBinaryOpExpression(
#     149             left=left, right=right, operator=expression._operator
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/expression_visitor.py in eval_expression(self, expression, **kwargs)
#     123 class IdentityTransform(ExpressionVisitor):
#     124     def eval_expression(self, expression: ColExprT, **kwargs) -> ColExprT:
# --> 125         ret = super().eval_expression(expression, **kwargs)
#     126         if hasattr(expression, "_dtype"):
#     127             ret._dtype = expression._dtype
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/expression_visitor.py in eval_expression(self, expression, **kwargs)
#      42         if not isinstance(expression, expr.ColumnExpression):
#      43             return self.eval_any(expression, **kwargs)
# ---> 44         return impl[type(expression)](expression, **kwargs)
#      45
#      46     @abstractmethod
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/type_interpreter.py in eval_binary_op(self, expression, state, **kwargs)
#     108         return _wrap(
#     109             expression,
# --> 110             self._eval_binary_op(
#     111                 left_dtype, right_dtype, expression._operator, expression
#     112             ),
#
# /usr/local/lib/python3.11/dist-packages/pathway/internals/type_interpreter.py in _eval_binary_op(self, left_dtype, right_dtype, operator, expression)
#     149
#     150         expression_info = get_expression_info(expression)
# --> 151         raise TypeError(
#     152             f"Pathway does not support using binary operator {operator.__name__}"
#     153             + f" on columns of types {original_left.typehint}, {original_right.typehint}.\n"
#
# TypeError: Pathway does not support using binary operator mul on columns of types <class 'float'>, typing.Any.
# It refers to the following expression:
# 	(0.1 * pathway.apply(vehicle_type_weight, <table1>.VehicleType))
# called in /tmp/ipython-input-3-4258632274.py:49
# with tables:
# 	<table1> created in /tmp/ipython-input-3-4258632274.py:39
